# %%
import subprocess

def sh(cmd):
    result = subprocess.run(cmd, shell=True, capture_output=True, text=True)
    print(result.stdout)
    if result.returncode != 0:
        print("STDERR:", result.stderr)
    return result

sh("docker --version")
sh("uname -m")
# Out:
# Docker version 29.1.3, build 29.1.3-0ubuntu4.1
#
# aarch64
# CompletedProcess(args='uname -m', returncode=0, stdout='aarch64\n', stderr='')

# %%
# %%writefile generate_dataset.py
# Generates the spam/ham dataset for Assignment 2
import argparse
import random
import pandas as pd

SPAM_TEMPLATES = [
    "WIN a FREE {prize} now! Click here: {url}",
    "Congratulations! You have WON a {prize}. Claim NOW at {url}",
    "URGENT: Your account will be suspended. Verify at {url}",
    "Limited time offer! Get {prize} FREE, click {url} today",
    "You've been selected for a {prize}! Reply YES to claim",
    "Cash prize alert: claim your {prize} before it expires! {url}",
]
HAM_TEMPLATES = [
    "Hey, are we still meeting for {activity} on {day}?",
    "Can you send me the notes from {activity} class?",
    "Don't forget about {activity} this {day}, see you there",
    "Thanks for helping with {activity} yesterday",
    "Running a bit late for {activity}, be there in 10 min",
    "What time does {activity} start on {day}?",
]
PRIZES = ["iPhone", "cash prize", "gift card", "vacation", "laptop"]
URLS = ["bit.ly/xyz123", "tinyurl.com/abc", "win-now.co/claim"]
ACTIVITIES = ["lunch", "the study group", "basketball", "the project meeting"]
DAYS = ["Monday", "Friday", "tomorrow", "the weekend"]


def generate():
    random.seed(42)
    rows = []
    for i in range(1000):
        if random.random() < 0.3:
            t = random.choice(SPAM_TEMPLATES)
            msg = t.format(prize=random.choice(PRIZES), url=random.choice(URLS))
            rows.append((msg, "spam"))
        else:
            t = random.choice(HAM_TEMPLATES)
            msg = t.format(activity=random.choice(ACTIVITIES), day=random.choice(DAYS))
            rows.append((msg, "ham"))
    return pd.DataFrame(rows, columns=["text", "label"])


if __name__ == "__main__":
    parser = argparse.ArgumentParser()
    parser.add_argument("--out", default="data/spam_dataset.csv")
    args = parser.parse_args()
    generate().to_csv(args.out, index=False)
# Out:
# Overwriting generate_dataset.py

# %%
import os

os.makedirs("data", exist_ok=True)
subprocess.run(["python3", "generate_dataset.py", "--out", "data/spam_dataset.csv"], check=True)
print("Dataset ready.")
# Out:
# Dataset ready.

# %%
# %%writefile train_and_export_model.py
# Trains TF-IDF + Naive Bayes on the spam dataset and saves it for the API
import argparse
import joblib
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import make_pipeline


def main():
    parser = argparse.ArgumentParser()
    parser.add_argument("--data", default="data/spam_dataset.csv")
    parser.add_argument("--out", default="data/model.joblib")
    args = parser.parse_args()

    df = pd.read_csv(args.data)
    X_train, X_test, y_train, y_test = train_test_split(
        df["text"], df["label"], test_size=0.2, random_state=42, stratify=df["label"])

    model = make_pipeline(TfidfVectorizer(), MultinomialNB())
    model.fit(X_train, y_train)

    preds = model.predict(X_test)
    print(f"accuracy={accuracy_score(y_test, preds):.4f}")

    joblib.dump(model, args.out)
    print(f"saved model to {args.out}")


if __name__ == "__main__":
    main()
# Out:
# Overwriting train_and_export_model.py

# %%
subprocess.run(["python3", "train_and_export_model.py"], check=True)
print(os.path.getsize("data/model.joblib"), "bytes")
# Out:
# accuracy=1.0000
# saved model to data/model.joblib
# 5889 bytes

# %%
# %%writefile spam_app.py
# Spam detection API
import os
import joblib
from fastapi import FastAPI, HTTPException
from pydantic import BaseModel

MODEL_PATH = os.environ.get("MODEL_PATH", "data/model.joblib")

app = FastAPI(title="Spam Detection API")
_model = None


@app.on_event("startup")
def load_model():
    global _model
    _model = joblib.load(MODEL_PATH)
    print(f"loaded model from {MODEL_PATH}")


class PredictRequest(BaseModel):
    text: str


@app.get("/healthz")
def healthz():
    if _model is None:
        raise HTTPException(status_code=503, detail="model not loaded")
    return {"status": "ok"}


@app.post("/predict")
def predict(request: PredictRequest):
    if _model is None:
        raise HTTPException(status_code=503, detail="model not loaded")
    return {"label": _model.predict([request.text]).tolist()[0]}
# Out:
# Overwriting spam_app.py

# %%
import subprocess, time, requests, os

env = os.environ.copy()
env.update({"MODEL_PATH": "data/model.joblib"})

proc = subprocess.Popen(
    ["uvicorn", "spam_app:app", "--host", "0.0.0.0", "--port", "28080"],
    env=env, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True,
)
time.sleep(3)

# %%
health = requests.get("http://localhost:28080/healthz")
print("Health check:", health.status_code, health.json())

for text in ["WIN a FREE iPhone now! Click here: bit.ly/xyz123",
             "Hey, are we still meeting for lunch on Friday?"]:
    pred = requests.post("http://localhost:28080/predict", json={"text": text}).json()
    print(text, "->", pred)
# Out:
# Health check: 200 {'status': 'ok'}
# WIN a FREE iPhone now! Click here: bit.ly/xyz123 -> {'label': 'spam'}
# Hey, are we still meeting for lunch on Friday? -> {'label': 'ham'}

# %%
proc.terminate()
proc.wait(timeout=5)
print("Local test server stopped.")
# Out:
# Local test server stopped.

# %%
# %%writefile requirements-predictor.txt
# fastapi
# uvicorn[standard]
# scikit-learn
# joblib
# pydantic
# Out:
# Overwriting requirements-predictor.txt

# %%
# %%writefile Dockerfile.naive
# FROM python:3.11
#
# WORKDIR /app
#
# COPY . .
# RUN pip install -r requirements-predictor.txt
#
# ENV MODEL_PATH=/app/data/model.joblib
#
# EXPOSE 8080
# CMD ["uvicorn", "spam_app:app", "--host", "0.0.0.0", "--port", "8080"]
# Out:
# Overwriting Dockerfile.naive

# %%
sh("docker run -d --name spam-naive -p 8080:8080 spam-api:naive")
time.sleep(5)
sh("docker ps")
# Out:
# 096f7979f9816ad9274a3695a34ea4269ad7e7b95f0a313655776ce5efd414ef
#
# CONTAINER ID   IMAGE                                 COMMAND                  CREATED         STATUS         PORTS                                                                                                                                  NAMES
# 096f7979f981   spam-api:naive                        "uvicorn spam_app:ap…"   5 seconds ago   Up 5 seconds   0.0.0.0:8080->8080/tcp, [::]:8080->8080/tcp                                                                                            spam-naive
# cb0c88ead612   gcr.io/k8s-minikube/kicbase:v0.0.51   "/usr/local/bin/entr…"   5 hours ago     Up 5 hours     127.0.0.1:32783->22/tcp, 127.0.0.1:32784->2376/tcp, 127.0.0.1:32785->5000/tcp, 127.0.0.1:32786->8443/tcp, 127.0.0.1:32787->32443/tcp   minikube-m02
# 0ab459d84bd5   gcr.io/k8s-minikube/kicbase:v0.0.51   "/usr/local/bin/entr…"   5 hours ago     Up 5 hours     127.0.0.1:32778->22/tcp, 127.0.0.1:32779->2376/tcp, 127.0.0.1:32780->5000/tcp, 127.0.0.1:32781->8443/tcp, 127.0.0.1:32782->32443/tcp   minikube
# CompletedProcess(args='docker ps', returncode=0, stdout='CONTAINER ID   IMAGE                                 COMMAND                  CREATED         STATUS         PORTS                                                                                                                                  NAMES\n096f7979f981   spam-api:naive                        "uvicorn spam_app:ap…"   5 seconds ago   Up 5 seconds   0.0.0.0:8080->8080/tcp, [::]:8080->8080/tcp                                                                                            spam-naive\ncb0c88ead612   gcr.io/k8s-minikube/kicbase:v0.0.51   "/usr/local/bin/entr…"   5 hours ago     Up 5 hours     127.0.0.1:32783->22/tcp, 127.0.0.1:32784->2376/tcp, 127.0.0.1:32785->5000/tcp, 127.0.0.1:32786->8443/tcp, 127.0.0.1:32787->32443/tcp   minikube-m02\n0ab459d84bd5   gcr.io/k8s-minikube/kicbase:v0.0.51   "/usr/local/bin/entr…"   5 hours ago     Up 5 hours     127.0.0.1:32778->22/tcp, 127.0.0.1:32779->2376/tcp, 127.0.0.1:32780->5000/tcp, 127.0.0.1:32781->8443/tcp, 127.0.0.1:32782->32443/tcp   minikube\n', stderr='')

# %%
health = requests.get("http://localhost:8080/healthz")
print("Health check:", health.status_code, health.json())

for text in ["WIN a FREE iPhone now! Click here: bit.ly/xyz123",
             "Hey, are we still meeting for lunch on Friday?"]:
    pred = requests.post("http://localhost:8080/predict", json={"text": text}).json()
    print(text, "->", pred)
# Out:
# Health check: 200 {'status': 'ok'}
# WIN a FREE iPhone now! Click here: bit.ly/xyz123 -> {'label': 'spam'}
# Hey, are we still meeting for lunch on Friday? -> {'label': 'ham'}

# %%
sh("docker images spam-api");
# Out:
# IMAGE                 ID             DISK USAGE   CONTENT SIZE   EXTRA
# spam-api:cache        3b880f1a2d97        697MB          149MB
# spam-api:multistage   f7df352a8b3e        678MB          145MB   U
# spam-api:naive        1e4cedd29aa7       2.19GB          565MB
# spam-api:v1           b5f47dd74806        689MB          148MB
# spam-api:v2           af4595e272a0        678MB          145MB

# %%
# %%writefile Dockerfile.multistage
# # Stage 1: install dependencies
# FROM python:3.11 AS builder
#
# WORKDIR /app
#
# RUN python -m venv /opt/venv
# ENV PATH="/opt/venv/bin:$PATH"
#
# COPY requirements-predictor.txt .
# RUN pip install --no-cache-dir -U pip
# RUN pip install --no-cache-dir -r requirements-predictor.txt
#
# # Stage 2: runtime
# FROM python:3.11-slim AS runner
#
# WORKDIR /app
#
# COPY --from=builder /opt/venv /opt/venv
# COPY spam_app.py .
# COPY data/model.joblib ./model.joblib
# ENV MODEL_PATH=/app/model.joblib
#
# ENV PATH="/opt/venv/bin:$PATH"
#
# EXPOSE 8080
# CMD ["uvicorn", "spam_app:app", "--host", "0.0.0.0", "--port", "8080"]
# Out:
# Overwriting Dockerfile.multistage

# %%
# !docker build -t spam-api:multistage -f Dockerfile.multistage .
# Out:
# [+] Building 0.0s (0/1)                                          docker:default
# [+] Building 0.2s (1/3)                                          docker:default
#  => [internal] load build definition from Dockerfile.multistage            0.0s
#  => => transferring dockerfile: 632B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        0.2s
#  => [internal] load metadata for docker.io/library/python:3.11             0.2s
# [+] Building 0.4s (1/3)                                          docker:default
#  => [internal] load build definition from Dockerfile.multistage            0.0s
#  => => transferring dockerfile: 632B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        0.3s
#  => [internal] load metadata for docker.io/library/python:3.11             0.3s
# [+] Building 0.5s (1/3)                                          docker:default
#  => [internal] load build definition from Dockerfile.multistage            0.0s
#  => => transferring dockerfile: 632B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        0.5s
#  => [internal] load metadata for docker.io/library/python:3.11             0.5s
# [+] Building 0.7s (1/3)                                          docker:default
#  => [internal] load build definition from Dockerfile.multistage            0.0s
#  => => transferring dockerfile: 632B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        0.6s
#  => [internal] load metadata for docker.io/library/python:3.11             0.6s
# [+] Building 0.8s (1/3)                                          docker:default
#  => [internal] load build definition from Dockerfile.multistage            0.0s
#  => => transferring dockerfile: 632B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        0.8s
#  => [internal] load metadata for docker.io/library/python:3.11             0.8s
# [+] Building 1.0s (1/3)                                          docker:default
#  => [internal] load build definition from Dockerfile.multistage            0.0s
#  => => transferring dockerfile: 632B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        0.9s
#  => [internal] load metadata for docker.io/library/python:3.11             0.9s
# [+] Building 1.1s (1/3)                                          docker:default
#  => [internal] load build definition from Dockerfile.multistage            0.0s
#  => => transferring dockerfile: 632B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        1.1s
#  => [internal] load metadata for docker.io/library/python:3.11             1.1s
# [+] Building 1.3s (1/3)                                          docker:default
#  => [internal] load build definition from Dockerfile.multistage            0.0s
#  => => transferring dockerfile: 632B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        1.2s
#  => [internal] load metadata for docker.io/library/python:3.11             1.2s
# [+] Building 1.3s (1/4)                                          docker:default
#  => [internal] load build definition from Dockerfile.multistage            0.0s
#  => => transferring dockerfile: 632B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        1.2s
#  => [internal] load metadata for docker.io/library/python:3.11             1.2s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
# [+] Building 1.4s (2/4)                                          docker:default
#  => [internal] load build definition from Dockerfile.multistage            0.0s
#  => => transferring dockerfile: 632B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        1.4s
#  => [internal] load metadata for docker.io/library/python:3.11             1.4s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
# [+] Building 1.6s (2/4)                                          docker:default
#  => [internal] load build definition from Dockerfile.multistage            0.0s
#  => => transferring dockerfile: 632B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        1.5s
#  => [internal] load metadata for docker.io/library/python:3.11             1.5s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
# [+] Building 1.7s (2/4)                                          docker:default
#  => [internal] load build definition from Dockerfile.multistage            0.0s
#  => => transferring dockerfile: 632B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        1.7s
#  => [internal] load metadata for docker.io/library/python:3.11             1.7s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
# [+] Building 1.9s (2/4)                                          docker:default
#  => [internal] load build definition from Dockerfile.multistage            0.0s
#  => => transferring dockerfile: 632B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        1.8s
#  => [internal] load metadata for docker.io/library/python:3.11             1.8s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
# [+] Building 2.0s (2/4)                                          docker:default
#  => [internal] load build definition from Dockerfile.multistage            0.0s
#  => => transferring dockerfile: 632B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        2.0s
#  => [internal] load metadata for docker.io/library/python:3.11             2.0s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
# [+] Building 2.2s (2/4)                                          docker:default
#  => [internal] load build definition from Dockerfile.multistage            0.0s
#  => => transferring dockerfile: 632B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        2.1s
#  => [internal] load metadata for docker.io/library/python:3.11             2.1s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
# [+] Building 2.3s (2/4)                                          docker:default
#  => [internal] load build definition from Dockerfile.multistage            0.0s
#  => => transferring dockerfile: 632B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        2.3s
#  => [internal] load metadata for docker.io/library/python:3.11             2.3s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
# [+] Building 2.5s (2/4)                                          docker:default
#  => [internal] load build definition from Dockerfile.multistage            0.0s
#  => => transferring dockerfile: 632B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        2.4s
#  => [internal] load metadata for docker.io/library/python:3.11             2.4s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
# [+] Building 2.6s (2/4)                                          docker:default
#  => [internal] load build definition from Dockerfile.multistage            0.0s
#  => => transferring dockerfile: 632B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        2.6s
#  => [internal] load metadata for docker.io/library/python:3.11             2.6s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
# [+] Building 2.8s (3/4)                                          docker:default
#  => [internal] load build definition from Dockerfile.multistage            0.0s
#  => => transferring dockerfile: 632B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        2.7s
#  => [internal] load metadata for docker.io/library/python:3.11             2.7s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
# [+] Building 2.9s (16/17)                                        docker:default
#  => [internal] load build definition from Dockerfile.multistage            0.0s
#  => => transferring dockerfile: 632B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        2.7s
#  => [internal] load metadata for docker.io/library/python:3.11             2.7s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [builder 1/6] FROM docker.io/library/python:3.11@sha256:3d39409d0b663  0.0s
#  => => resolve docker.io/library/python:3.11@sha256:3d39409d0b663c788775e  0.0s
#  => [runner 1/5] FROM docker.io/library/python:3.11-slim@sha256:da047cb8f  0.0s
#  => => resolve docker.io/library/python:3.11-slim@sha256:da047cb8f9d1d98e  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 6.93kB                                        0.0s
#  => CACHED [runner 2/5] WORKDIR /app                                       0.0s
#  => CACHED [builder 2/6] WORKDIR /app                                      0.0s
#  => CACHED [builder 3/6] RUN python -m venv /opt/venv                      0.0s
#  => CACHED [builder 4/6] COPY requirements-predictor.txt .                 0.0s
#  => CACHED [builder 5/6] RUN pip install --no-cache-dir -U pip             0.0s
#  => CACHED [builder 6/6] RUN pip install --no-cache-dir -r requirements-p  0.0s
#  => CACHED [runner 3/5] COPY --from=builder /opt/venv /opt/venv            0.0s
#  => [runner 4/5] COPY spam_app.py .                                        0.0s
# [+] Building 3.0s (17/18)                                        docker:default
#  => [internal] load metadata for docker.io/library/python:3.11-slim        2.7s
#  => [internal] load metadata for docker.io/library/python:3.11             2.7s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [builder 1/6] FROM docker.io/library/python:3.11@sha256:3d39409d0b663  0.0s
#  => => resolve docker.io/library/python:3.11@sha256:3d39409d0b663c788775e  0.0s
#  => [runner 1/5] FROM docker.io/library/python:3.11-slim@sha256:da047cb8f  0.0s
#  => => resolve docker.io/library/python:3.11-slim@sha256:da047cb8f9d1d98e  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 6.93kB                                        0.0s
#  => CACHED [runner 2/5] WORKDIR /app                                       0.0s
#  => CACHED [builder 2/6] WORKDIR /app                                      0.0s
#  => CACHED [builder 3/6] RUN python -m venv /opt/venv                      0.0s
#  => CACHED [builder 4/6] COPY requirements-predictor.txt .                 0.0s
#  => CACHED [builder 5/6] RUN pip install --no-cache-dir -U pip             0.0s
#  => CACHED [builder 6/6] RUN pip install --no-cache-dir -r requirements-p  0.0s
#  => CACHED [runner 3/5] COPY --from=builder /opt/venv /opt/venv            0.0s
#  => [runner 4/5] COPY spam_app.py .                                        0.0s
#  => [runner 5/5] COPY data/model.joblib ./model.joblib                     0.0s
#  => exporting to image                                                     0.1s
#  => => exporting layers                                                    0.1s
# [+] Building 3.2s (17/18)                                        docker:default
#  => => resolve docker.io/library/python:3.11@sha256:3d39409d0b663c788775e  0.0s
#  => [runner 1/5] FROM docker.io/library/python:3.11-slim@sha256:da047cb8f  0.0s
#  => => resolve docker.io/library/python:3.11-slim@sha256:da047cb8f9d1d98e  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 6.93kB                                        0.0s
#  => CACHED [runner 2/5] WORKDIR /app                                       0.0s
#  => CACHED [builder 2/6] WORKDIR /app                                      0.0s
#  => CACHED [builder 3/6] RUN python -m venv /opt/venv                      0.0s
#  => CACHED [builder 4/6] COPY requirements-predictor.txt .                 0.0s
#  => CACHED [builder 5/6] RUN pip install --no-cache-dir -U pip             0.0s
#  => CACHED [builder 6/6] RUN pip install --no-cache-dir -r requirements-p  0.0s
#  => CACHED [runner 3/5] COPY --from=builder /opt/venv /opt/venv            0.0s
#  => [runner 4/5] COPY spam_app.py .                                        0.0s
#  => [runner 5/5] COPY data/model.joblib ./model.joblib                     0.0s
#  => exporting to image                                                     0.2s
#  => => exporting layers                                                    0.1s
#  => => exporting manifest sha256:4a808778092a96163b0037c65470ccfe9fde2654  0.0s
#  => => exporting config sha256:1fc10272fe6066783aef4fddf89dff83931512fd0e  0.0s
#  => => exporting attestation manifest sha256:074e4f06bd3c70ba69bdf15a5882  0.0s
#  => => exporting manifest list sha256:f7df352a8b3e76b231c6fae3018a1d3e3c9  0.0s
#  => => naming to docker.io/library/spam-api:multistage                     0.0s
#  => => unpacking to docker.io/library/spam-api:multistage                  0.1s
# [+] Building 3.3s (18/18) FINISHED                               docker:default
#  => [internal] load build definition from Dockerfile.multistage            0.0s
#  => => transferring dockerfile: 632B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        2.7s
#  => [internal] load metadata for docker.io/library/python:3.11             2.7s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [builder 1/6] FROM docker.io/library/python:3.11@sha256:3d39409d0b663  0.0s
#  => => resolve docker.io/library/python:3.11@sha256:3d39409d0b663c788775e  0.0s
#  => [runner 1/5] FROM docker.io/library/python:3.11-slim@sha256:da047cb8f  0.0s
#  => => resolve docker.io/library/python:3.11-slim@sha256:da047cb8f9d1d98e  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 6.93kB                                        0.0s
#  => CACHED [runner 2/5] WORKDIR /app                                       0.0s
#  => CACHED [builder 2/6] WORKDIR /app                                      0.0s
#  => CACHED [builder 3/6] RUN python -m venv /opt/venv                      0.0s
#  => CACHED [builder 4/6] COPY requirements-predictor.txt .                 0.0s
#  => CACHED [builder 5/6] RUN pip install --no-cache-dir -U pip             0.0s
#  => CACHED [builder 6/6] RUN pip install --no-cache-dir -r requirements-p  0.0s
#  => CACHED [runner 3/5] COPY --from=builder /opt/venv /opt/venv            0.0s
#  => [runner 4/5] COPY spam_app.py .                                        0.0s
#  => [runner 5/5] COPY data/model.joblib ./model.joblib                     0.0s
#  => exporting to image                                                     0.3s
#  => => exporting layers                                                    0.1s
#  => => exporting manifest sha256:4a808778092a96163b0037c65470ccfe9fde2654  0.0s
#  => => exporting config sha256:1fc10272fe6066783aef4fddf89dff83931512fd0e  0.0s
#  => => exporting attestation manifest sha256:074e4f06bd3c70ba69bdf15a5882  0.0s
#  => => exporting manifest list sha256:f7df352a8b3e76b231c6fae3018a1d3e3c9  0.0s
#  => => naming to docker.io/library/spam-api:multistage                     0.0s
#  => => unpacking to docker.io/library/spam-api:multistage                  0.1s

# %%
sh("docker rm -f spam-multi")
sh("docker run -d --name spam-multi -p 8080:8080 spam-api:multistage")
time.sleep(5)
sh("docker ps");
# Out:
# dd9f22c8ec34f98be615a2b1287aaadbef395d93cdfa4614a965724051a0ca46
#
# CONTAINER ID   IMAGE                                 COMMAND                  CREATED         STATUS         PORTS                                                                                                                                  NAMES
# dd9f22c8ec34   spam-api:multistage                   "uvicorn spam_app:ap…"   5 seconds ago   Up 5 seconds   0.0.0.0:8080->8080/tcp, [::]:8080->8080/tcp                                                                                            spam-multi
# cb0c88ead612   gcr.io/k8s-minikube/kicbase:v0.0.51   "/usr/local/bin/entr…"   5 hours ago     Up 5 hours     127.0.0.1:32783->22/tcp, 127.0.0.1:32784->2376/tcp, 127.0.0.1:32785->5000/tcp, 127.0.0.1:32786->8443/tcp, 127.0.0.1:32787->32443/tcp   minikube-m02
# 0ab459d84bd5   gcr.io/k8s-minikube/kicbase:v0.0.51   "/usr/local/bin/entr…"   5 hours ago     Up 5 hours     127.0.0.1:32778->22/tcp, 127.0.0.1:32779->2376/tcp, 127.0.0.1:32780->5000/tcp, 127.0.0.1:32781->8443/tcp, 127.0.0.1:32782->32443/tcp   minikube

# %%
health = requests.get("http://localhost:8080/healthz")
print("Health check:", health.status_code, health.json())

for text in ["WIN a FREE iPhone now! Click here: bit.ly/xyz123",
             "Hey, are we still meeting for lunch on Friday?"]:
    pred = requests.post("http://localhost:8080/predict", json={"text": text}).json()
    print(text, "->", pred)
# Out:
# Health check: 200 {'status': 'ok'}
# WIN a FREE iPhone now! Click here: bit.ly/xyz123 -> {'label': 'spam'}
# Hey, are we still meeting for lunch on Friday? -> {'label': 'ham'}

# %%
sh("docker images spam-api")
# Out:
# IMAGE                 ID             DISK USAGE   CONTENT SIZE   EXTRA
# spam-api:cache        3b880f1a2d97        697MB          149MB
# spam-api:multistage   f7df352a8b3e        678MB          145MB   U
# spam-api:naive        1e4cedd29aa7       2.19GB          565MB
# spam-api:v1           b5f47dd74806        689MB          148MB
# spam-api:v2           af4595e272a0        678MB          145MB
# CompletedProcess(args='docker images spam-api', returncode=0, stdout='IMAGE                 ID             DISK USAGE   CONTENT SIZE   EXTRA\nspam-api:cache        3b880f1a2d97        697MB          149MB        \nspam-api:multistage   f7df352a8b3e        678MB          145MB   U    \nspam-api:naive        1e4cedd29aa7       2.19GB          565MB        \nspam-api:v1           b5f47dd74806        689MB          148MB        \nspam-api:v2           af4595e272a0        678MB          145MB        \n', stderr='WARNING: This output is designed for human readability. For machine-readable output, please use --format.\n')

# %%
sh("docker history spam-api:naive --format 'table {{.Size}}\t{{.CreatedBy}}'")
sh("docker history spam-api:multistage --format 'table {{.Size}}\t{{.CreatedBy}}'");
# Out:
# SIZE      CREATED BY
# 0B        CMD ["uvicorn" "spam_app:app" "--host" "0.0.…
# 0B        EXPOSE [8080/tcp]
# 0B        ENV MODEL_PATH=/app/data/model.joblib
# 427MB     RUN /bin/sh -c pip install -r requirements-p…
# 131kB     COPY . . # buildkit
# 8.19kB    WORKDIR /app
# 0B        CMD ["python3"]
# 16.4kB    RUN /bin/sh -c set -eux;  for src in idle3 p…
# 73.4MB    RUN /bin/sh -c set -eux;   wget -O python.ta…
# 0B        ENV PYTHON_SHA256=91bcdebfdde239a003ae93738a…
# 0B        ENV PYTHON_VERSION=3.11.16
# 0B        ENV GPG_KEY=A035C8C19219BA821ECEA86B64E628F8…
# 20.5MB    RUN /bin/sh -c set -eux;  apt-get update;  a…
# 0B        ENV LANG=C.UTF-8
# 0B        ENV PATH=/usr/local/bin:/usr/local/sbin:/usr…
# 679MB     RUN /bin/sh -c set -ex;  apt-get update;  ap…
# 208MB     RUN /bin/sh -c set -eux;  apt-get update;  a…
# 63.7MB    RUN /bin/sh -c set -eux;  apt-get update;  a…
# 156MB     # debian.sh --arch 'arm64' out/ 'trixie' '@1…
#
# SIZE      CREATED BY
# 0B        CMD ["uvicorn" "spam_app:app" "--host" "0.0.…
# 0B        EXPOSE [8080/tcp]
# 0B        ENV PATH=/opt/venv/bin:/usr/local/bin:/usr/l…
# 0B        ENV MODEL_PATH=/app/model.joblib
# 16.4kB    COPY data/model.joblib ./model.joblib # buil…
# 12.3kB    COPY spam_app.py . # buildkit
# 367MB     COPY /opt/venv /opt/venv # buildkit
# 8.19kB    WORKDIR /app
# 0B        CMD ["python3"]
# 16.4kB    RUN /bin/sh -c set -eux;  for src in idle3 p…
# 52.1MB    RUN /bin/sh -c set -eux;   savedAptMark="$(a…
# 0B        ENV PYTHON_SHA256=91bcdebfdde239a003ae93738a…
# 0B        ENV PYTHON_VERSION=3.11.16
# 0B        ENV GPG_KEY=A035C8C19219BA821ECEA86B64E628F8…
# 4.99MB    RUN /bin/sh -c set -eux;  apt-get update;  a…
# 0B        ENV LANG=C.UTF-8
# 0B        ENV PATH=/usr/local/bin:/usr/local/sbin:/usr…
# 110MB     # debian.sh --arch 'arm64' out/ 'trixie' '@1…
